# %%
# NB!!!
# Basta avviare una volta sola ad inizio sessione.
# Drive verrà montato per tutto il notebook

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
#
#
# # **DATAFRAME**
#
#
# ---

# %% [markdown]
# ![pandas_dataframe.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

data_src = {
    "Costruttore": ["Fiat", "Lancia", "Ford"],
    "Modello": ["500L", "Prisma", "Escort"],
    "Prezzo":  [15000, 12000, 20000]
}

df_auto = pd.DataFrame(data_src)
display(df_auto)
# Out:
#   Costruttore Modello  Prezzo
# 0        Fiat    500L   15000
# 1      Lancia  Prisma   12000
# 2        Ford  Escort   20000

# %%
df_trees = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ai_ml_py_2022_2024/dataset/trees.csv', sep=',' , encoding = 'latin1')
display(df_trees)
# Out:
#     Id  Circonferenza  Altezza  Volume
# 0    1            8.3       70    10.3
# 1    2            8.6       65    10.3
# 2    3            8.8       63    10.2
# 3    4           10.5       72    16.4
# 4    5           10.7       81    18.8
# 5    6           10.8       83    19.7
# 6    7           11.0       66    15.6
# 7    8           11.0       75    18.2
# 8    9           11.1       80    22.6
# 9   10           11.2       75    19.9
# 10  11           11.3       79    24.2
# 11  12           11.4       76    21.0
# 12  13           11.4       76    21.4
# 13  14           11.7       69    21.3
# 14  15           12.0       75    19.1
# 15  16           12.9       74    22.2
# 16  17           12.9       85    33.8
# 17  18           13.3       86    27.4
# 18  19           13.7       71    25.7
# 19  20           13.8       64    24.9
# 20  21           14.0       78    34.5
# 21  22           14.2       80    31.7
# 22  23           14.5       74    36.3
# ...

# %% [markdown]
# **Info**

# %%
df_trees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             31 non-null     int64
#  1   Circonferenza  31 non-null     float64
#  2   Altezza        31 non-null     int64
#  3   Volume         31 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 1.1 KB

# %%
# mostra il numero di righe e colonne
df_trees.shape
# Out:
# (31, 4)

# %%
# mostra il range di dati per colonna
df_trees.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
# mostra tutte le etichette delle colonne
df_trees.columns
# Out:
# Index(['Id', 'Circonferenza', 'Altezza', 'Volume'], dtype='object')

# %%
# mostra il numero di valori per ogni colonna
df_trees.count()
# Out:
# Id               31
# Circonferenza    31
# Altezza          31
# Volume           31
# dtype: int64

# %% [markdown]
# **Summary**

# %% [markdown]
# # **ACCESSO AD UN DATAFRAME**

# %% [markdown]
# **By position**
#
# **`iloc[[0], [2]]`**
#
#  restituisce la riga e la colonna alla posizione indicata
#
# **`[0]`** il primo indice accede alle righe
#
# **`[2]`** il secondo indice accede alle colonne

# %%
tmp_val = df_auto.iloc[[0], [2]]
display(tmp_val)
# Out:
#    Prezzo
# 0   15000

# %% [markdown]
# **At position**
#
# **`iat[0, 2]`**
#
#  restituisce solo il singolo valore corrispondente a riga e colonna indicate
#
#   **`0`** il primo indice accede agli indici
#
#  **`2`** il secondo indice accede alle colonne

# %%
display(df_auto.iat[0, 2])
# Out:
# 15000

# %% [markdown]
# **By label**
#
# **`loc[[2], ["Circonferenza"]]`**
#
# Restituisce  la riga 2 nella colonna "Circonferenza"

# %%
display(df_trees.loc[[2], ["Circonferenza"]])
# Out:
#    Circonferenza
# 2            8.8

# %% [markdown]
# **At label**
#
# **`loc[[2], ["Circonferenza"]]`**
#
# Restituisce il valore individuato dalla riga 2 nella colonna "Circonferenza"

# %%
display(df_trees.at[2, "Circonferenza"])
# Out:
# 8.8

# %% [markdown]
# **By column**
#
# restituisce l'intero dontenuto di una o più colonne

# %%
display(df_trees[["Id", "Circonferenza"]])
# Out:
#     Id  Circonferenza
# 0    1            8.3
# 1    2            8.6
# 2    3            8.8
# 3    4           10.5
# 4    5           10.7
# 5    6           10.8
# 6    7           11.0
# 7    8           11.0
# 8    9           11.1
# 9   10           11.2
# 10  11           11.3
# 11  12           11.4
# 12  13           11.4
# 13  14           11.7
# 14  15           12.0
# 15  16           12.9
# 16  17           12.9
# 17  18           13.3
# 18  19           13.7
# 19  20           13.8
# 20  21           14.0
# 21  22           14.2
# 22  23           14.5
# 23  24           16.0
# 24  25           16.3
# 25  26           17.3
# 26  27           17.5
# 27  28           17.9
# 28  29           18.0
# 29  30           18.0
# 30  31           20.6

# %% [markdown]
# **By row**
#
# Restituisce tutti i termini di una riga

# %%
display(df_trees.iloc[0])
# Out:
# Id                1.0
# Circonferenza     8.3
# Altezza          70.0
# Volume           10.3
# Name: 0, dtype: float64

# %% [markdown]
# **Bolean indexing**
#
# Filtra un dataset attraverso delle maschere

# %%
# crea una maschera di selezione che esclude tutte le righe che hanno i valori  minori di 20,
# in corrispondenza della colonna "Circonferenza"
mask_1 = df_trees["Circonferenza"] < 12

display(mask_1)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: Circonferenza, dtype: bool

# %%
# filtra il dataset utilizzando una maschera
df_mask_1 = df_trees[mask_1]

display(df_mask_1)
# Out:
#     Id  Circonferenza  Altezza  Volume
# 0    1            8.3       70    10.3
# 1    2            8.6       65    10.3
# 2    3            8.8       63    10.2
# 3    4           10.5       72    16.4
# 4    5           10.7       81    18.8
# 5    6           10.8       83    19.7
# 6    7           11.0       66    15.6
# 7    8           11.0       75    18.2
# 8    9           11.1       80    22.6
# 9   10           11.2       75    19.9
# 10  11           11.3       79    24.2
# 11  12           11.4       76    21.0
# 12  13           11.4       76    21.4
# 13  14           11.7       69    21.3

# %% [markdown]
# # **UTILS**

# %%
df_batman = pd.DataFrame(dict(age=[5, 6, np.NaN],
                              born=[pd.NaT, pd.Timestamp('1939-05-27'), pd.Timestamp('1940-04-25')],
                              name=['Alfred', 'Batman', ''],
                              toy=[None, 'Batmobile', 'Joker']))

display(df_batman)
# Out:
#    age       born    name        toy
# 0  5.0        NaT  Alfred       None
# 1  6.0 1939-05-27  Batman  Batmobile
# 2  NaN 1940-04-25              Joker

# %% [markdown]
# **Mappare elementi vuoti**

# %%
display(df_batman.isna())
# Out:
#      age   born   name    toy
# 0  False   True  False   True
# 1  False  False  False  False
# 2   True  False  False  False

# %% [markdown]
# **Eliminare elementi vuoti**

# %%
display(df_batman.dropna())
# Out:
#    age       born    name        toy
# 1  6.0 1939-05-27  Batman  Batmobile

# %% [markdown]
# **Riempire elementi vuoti**

# %%
display(df_batman.fillna(0.0))
# Out:
#    age                 born    name        toy
# 0  5.0                  0.0  Alfred        0.0
# 1  6.0  1939-05-27 00:00:00  Batman  Batmobile
# 2  0.0  1940-04-25 00:00:00              Joker

# %% [markdown]
# # **MODIFICA DEI DATAFRAME**

# %%
df1 = pd.DataFrame({"Col1": [1, 2, 3],
                    "Col2": ["A", "B", "C"],
                    "Col3": ["Ford", "Fiat", "Opel"]})


df2 = pd.DataFrame({"C1": [4, 5, 6],
                    "C2": ["D", "E", "F"]})

# %% [markdown]
# **Joint di DataFrame**

# %%
# aggiungere una colonVolumena di un DataFrame ad un altro
df_j = df2.join(df1['Col3'])

display(df_j)
# Out:
#    C1 C2  Col3
# 0   4  D  Ford
# 1   5  E  Fiat
# 2   6  F  Opel

# %% [markdown]
# **Concatenazione di DataFrame**

# %%
df_c = pd.concat([df1, df2], axis=1)
display(df_c)
# Out:
#    Col1 Col2  Col3  C1 C2
# 0     1    A  Ford   4  D
# 1     2    B  Fiat   5  E
# 2     3    C  Opel   6  F

# %% [markdown]
# **Ordinamento**

# %%
data = {'Name': ['Ben', 'Anna', 'Zoe', 'Tom', 'John', 'Steve', 'Becky', 'Bob'],
            'Score':  [1, 4, 3, 2, 1, 1, 2, 2],
            'Age': [20, 27, 20, 43, 30, 20, 22, 21]}

df_names = pd.DataFrame(data)

display(df_names)
# Out:
#     Name  Score  Age
# 0    Ben      1   20
# 1   Anna      4   27
# 2    Zoe      3   20
# 3    Tom      2   43
# 4   John      1   30
# 5  Steve      1   20
# 6  Becky      2   22
# 7    Bob      2   21

# %% [markdown]
# **`sort_values()`**
#
# Ordina gli elementi di un DataFrame usando l'etichetta di una colonna.
#
#
# **`by `**
#
# indica la colonna da usare come maschera
#
#
#
# **`inplace `**
#
# indica se il dataframe di partenza deve essere definitivamente modificato

# %%
df_names.sort_values( by=['Age'],  inplace=True)

display(df_names)
# Out:
#     Name  Score  Age
# 0    Ben      1   20
# 2    Zoe      3   20
# 5  Steve      1   20
# 7    Bob      2   21
# 6  Becky      2   22
# 1   Anna      4   27
# 4   John      1   30
# 3    Tom      2   43

# %% [markdown]
# **`sort_index()`**
#
# Ordina gli elementi di un DataFrame attraverso gli indici delle righe.

# %%
copy_fn_names = df_names.sort_index()
display(copy_fn_names)
# Out:
#     Name  Score  Age
# 0    Ben      1   20
# 1   Anna      4   27
# 2    Zoe      3   20
# 3    Tom      2   43
# 4   John      1   30
# 5  Steve      1   20
# 6  Becky      2   22
# 7    Bob      2   21

# %% [markdown]
# **Inserimento**

# %%
import numpy as np


cl =  [24.5, 22.2, 25.2, 30., 29, 26., 27.5, 26.3]

# inserisce una nuova colonna in seconda posizine (indice 1), con nome "Time" e valori
# presi dall'array cl
df_names.insert(1, "Time", cl)

display(df_names)
# Out:
#     Name  Time  Score  Age
# 0    Ben  24.5      1   20
# 2    Zoe  22.2      3   20
# 5  Steve  25.2      1   20
# 7    Bob  30.0      2   21
# 6  Becky  29.0      2   22
# 1   Anna  26.0      4   27
# 4   John  27.5      1   30
# 3    Tom  26.3      2   43

# %% [markdown]
# **Rimozione**

# %% [markdown]
# ![pandas_axis.jpg](data:image/jpeg;base64,...)

# %%
df_names = df_names.drop(['Time'], axis=1)
display(df_names)
# Out:
#     Name  Score  Age
# 0    Ben      1   20
# 2    Zoe      3   20
# 5  Steve      1   20
# 7    Bob      2   21
# 6  Becky      2   22
# 1   Anna      4   27
# 4   John      1   30
# 3    Tom      2   43

# %% [markdown]
# **Plotting**

# %%
import matplotlib.pyplot as plt

df_trees.plot.scatter(x="Altezza", y='Volume')
plt.show()

# %%
df_trees.plot.line()
plt.legend(bbox_to_anchor=(1., 1.02))
plt.show()

# %%
df_trees["Volume"].plot.hist()
plt.show()
